# %%
import pandas as pd
# importing classifiers and function for evaluation metrics
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
# importing functions for later use
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeRegressor
import plotly.express as px

# %% [markdown]
# Hypotheses:
#     It will be easiest to predict center and point guards because they are typically at the extremes of height, wingspan, rebounding, and assists
#     Height, Wingspan, TRB%, AST%, STL%, and BLK% will be the best indicators of position

# %% [markdown]
# Defining Functions to be used in cleaning data

# %%
def find_pos(string):
    '''
    finds the position of the player
    
    Args:
        string (str) the value in column name that contains the player's name, position, and team
    '''
    if string[-1] == 'C':
        return string[-1]
    else:
        return string[-2:]
def find_team(string):
    '''
    finds the team of the player
    
    Args:
        string (str) the value in column name that contains the player's name, position, and team
    '''
    if string[-1] == 'C':
        return string[-7:-4]
    else:
        return string[-8:-5]
def keep_only_name(string):
    '''
    returns only the player's name
    
    Args:
        string (str) the value in column name that contains the player's name, position, and team
    '''
    if string[-1] == 'C':
        return string[:-7]
    else:
        return string[:-8]
def feet_to_inches(string):
    '''
    Converts wingspan and height figures to inches by parsing strings i.e. 6'0" -> 72 
    
    Args:
        string (str) height or wingspan description
    '''
    feet = string[0]
    apos = False
    inches = ''
    for char in range(len(string)):
        if (char > 1 and char < len(string) - 1):
            inches += string[char]
    return int(feet) * 12 + float(inches)

# %% [markdown]
# Importing and Cleaning Wingspan and Height Data

# %%
wingspan_data = pd.read_csv('Wingspan Data.csv')
wingspan_data['position'] = wingspan_data['Name'].apply(find_pos)
wingspan_data['team'] = wingspan_data['Name'].apply(find_team)
wingspan_data['Name'] = wingspan_data['Name'].apply(keep_only_name)
wingspan_data['height'] = wingspan_data['height'].apply(feet_to_inches)
wingspan_data['wingspan'] = wingspan_data['wingspan'].apply(feet_to_inches)

# %% [markdown]
# Importing and Cleaning player stats data

# %%
import unidecode
player_stats = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2021_advanced.html')[0]
player_stats = player_stats.append(pd.read_html('https://www.basketball-reference.com/leagues/NBA_2020_advanced.html')[0])
player_stats = player_stats.append(pd.read_html('https://www.basketball-reference.com/leagues/NBA_2019_advanced.html')[0])
# A few values for Player Name are 'Player' which can be deleted
player_stats = player_stats[player_stats.Player != 'Player']
player_stats = player_stats.rename(columns = {'Player': 'Name', 'Tm': 'team'})
# Takes any accents out of player names
player_stats['Name'] = player_stats['Name'].map(unidecode.unidecode)
# Accounting for differences in team abbreviations
abbrev_diffs = {'CHO': 'CHA', 'BKN': 'BRK', 'PHO': 'PHX'}
wingspan_data['team'].replace(abbrev_diffs, inplace = True)
player_stats['team'].replace(abbrev_diffs, inplace = True)

# %% [markdown]
# Combining wingspan, height, and player stats data and Cleaning

# %%
player_final = player_stats.merge(wingspan_data, left_on = ['Name'], right_on = ['Name'], how = 'inner')
num_cols = player_final.drop(columns = ['Name', 'team_x', 'team_y', 'Pos', 'position']).columns
for col in num_cols:
    player_final[col] = player_final[col].apply(float)
player_final['M'] = player_final['MP'] / player_final['G']
# Keeping only players that played more than 20 mins per game and played in more than 20 games
player_final = player_final[(player_final.M > 20) & (player_final.G > 20)]

# %%
len(player_final)
# Out:
# 712

# %% [markdown]
# Visualizing player attributes against position to see the distribution across the league and look into outliers

# %%
px.scatter(player_final, x = 'position', y = 'height', color = 'Name')
# Out:
# <div>                            <div id="3cdc2e73-97c2-400a-9a7a-07592ea80af9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cdc2e73-97c2-400a-9a7a-07592ea80af9")) {                    Plotly.newPlot(                        "3cdc2e73-97c2-400a-9a7a-07592ea80af9",                        [{"hovertemplate": "Name=Steven Adams<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Steven Adams", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Steven Adams", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [82.75, 82.75, 82.75], "yaxis": "y"}, {"hovertemplate": "Name=Bam Adebayo<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Bam Adebayo", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Bam Adebayo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [80.75, 80.75, 80.75], "yaxis": "y"}, {"hovertemplate": "Name=LaMarcus Aldridge<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "LaMarcus Aldridge", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "LaMarcus Aldridge", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [82.0, 82.0, 82.0, 82.0], "yaxis": "y"}, {"hovertemplate": "Name=Nickeil Alexander-Walker<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Nickeil Alexander-Walker", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Nickeil Alexander-Walker", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [76.25], "yaxis": "y"}, {"hovertemplate": "Name=Grayson Allen<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Grayson Allen", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Grayson Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [75.0], "yaxis": "y"}, {"hovertemplate": "Name=Jarrett Allen<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Jarrett Allen", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Jarrett Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [81.0, 81.0, 81.0, 81.0], "yaxis": "y"}, {"hovertemplate": "Name=Kyle Anderson<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Kyle Anderson", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Kyle Anderson", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF"], "xaxis": "x", "y": [79.5, 79.5], "yaxis": "y"}, {"hovertemplate": "Name=Giannis Antetokounmpo<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Giannis Antetokounmpo", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Giannis Antetokounmpo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "PF", "PF"], "xaxis": "x", "y": [83.0, 83.0, 83.0], "yaxis": "y"}, {"hovertemplate": "Name=Cole Anthony<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "Cole Anthony", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Cole Anthony", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PG"], "xaxis": "x", "y": [74.0], "yaxis": "y"}, {"hovertemplate": "Name=OG Anunoby<br>position=%{x}<br>height=%{y}<extra></extra>", "legendgroup": "OG Anunoby", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "OG Anunoby", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF", "SF"], "xaxis": "x" ...

# %%
px.scatter(player_final, x = 'position', y = 'wingspan', color = 'Name')
# Out:
# <div>                            <div id="a955c298-59c3-426d-b295-ad74318a74f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a955c298-59c3-426d-b295-ad74318a74f4")) {                    Plotly.newPlot(                        "a955c298-59c3-426d-b295-ad74318a74f4",                        [{"hovertemplate": "Name=Steven Adams<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Steven Adams", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Steven Adams", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [88.5, 88.5, 88.5], "yaxis": "y"}, {"hovertemplate": "Name=Bam Adebayo<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Bam Adebayo", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Bam Adebayo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [86.75, 86.75, 86.75], "yaxis": "y"}, {"hovertemplate": "Name=LaMarcus Aldridge<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "LaMarcus Aldridge", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "LaMarcus Aldridge", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [88.75, 88.75, 88.75, 88.75], "yaxis": "y"}, {"hovertemplate": "Name=Nickeil Alexander-Walker<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Nickeil Alexander-Walker", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Nickeil Alexander-Walker", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [81.5], "yaxis": "y"}, {"hovertemplate": "Name=Grayson Allen<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Grayson Allen", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Grayson Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [79.25], "yaxis": "y"}, {"hovertemplate": "Name=Jarrett Allen<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Jarrett Allen", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Jarrett Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [89.25, 89.25, 89.25, 89.25], "yaxis": "y"}, {"hovertemplate": "Name=Kyle Anderson<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Kyle Anderson", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Kyle Anderson", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF"], "xaxis": "x", "y": [86.75, 86.75], "yaxis": "y"}, {"hovertemplate": "Name=Giannis Antetokounmpo<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Giannis Antetokounmpo", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Giannis Antetokounmpo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "PF", "PF"], "xaxis": "x", "y": [87.0, 87.0, 87.0], "yaxis": "y"}, {"hovertemplate": "Name=Cole Anthony<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "Cole Anthony", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Cole Anthony", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PG"], "xaxis": "x", "y": [76.5], "yaxis": "y"}, {"hovertemplate": "Name=OG Anunoby<br>position=%{x}<br>wingspan=%{y}<extra></extra>", "legendgroup": "OG Anunoby", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "OG Anunoby", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF" ...

# %%
px.scatter(player_final, x = 'position', y = 'TRB%', color = 'Name')
# Out:
# <div>                            <div id="885acd11-077a-4b12-8419-ad58ad2bb566" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("885acd11-077a-4b12-8419-ad58ad2bb566")) {                    Plotly.newPlot(                        "885acd11-077a-4b12-8419-ad58ad2bb566",                        [{"hovertemplate": "Name=Steven Adams<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Steven Adams", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Steven Adams", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [17.4, 19.2, 14.7], "yaxis": "y"}, {"hovertemplate": "Name=Bam Adebayo<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Bam Adebayo", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Bam Adebayo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "PF", "C"], "xaxis": "x", "y": [15.3, 17.0, 16.6], "yaxis": "y"}, {"hovertemplate": "Name=LaMarcus Aldridge<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "LaMarcus Aldridge", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "LaMarcus Aldridge", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [9.4, 9.2, 12.0, 15.1], "yaxis": "y"}, {"hovertemplate": "Name=Nickeil Alexander-Walker<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Nickeil Alexander-Walker", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Nickeil Alexander-Walker", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [7.8], "yaxis": "y"}, {"hovertemplate": "Name=Grayson Allen<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Grayson Allen", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Grayson Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [6.7], "yaxis": "y"}, {"hovertemplate": "Name=Jarrett Allen<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Jarrett Allen", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Jarrett Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [18.9, 18.3, 18.7, 16.8], "yaxis": "y"}, {"hovertemplate": "Name=Kyle Anderson<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Kyle Anderson", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Kyle Anderson", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "SF"], "xaxis": "x", "y": [11.1, 11.0], "yaxis": "y"}, {"hovertemplate": "Name=Giannis Antetokounmpo<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Giannis Antetokounmpo", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Giannis Antetokounmpo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "PF", "PF"], "xaxis": "x", "y": [17.5, 22.1, 19.3], "yaxis": "y"}, {"hovertemplate": "Name=Cole Anthony<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "Cole Anthony", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Cole Anthony", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PG"], "xaxis": "x", "y": [9.0], "yaxis": "y"}, {"hovertemplate": "Name=OG Anunoby<br>Pos=%{x}<br>TRB%=%{y}<extra></extra>", "legendgroup": "OG Anunoby", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "OG Anunoby", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF", "SF"], "xaxis": "x", "y": [9.1, 9.3, 7.9], "yaxis": "y"}, {"hovertemplate": "Name=Trevor Ariza<br>Po ...

# %%
px.scatter(player_final, x = 'position', y = 'TS%', color = 'Name')
# Out:
# <div>                            <div id="d59f1adc-846e-450f-bcaf-8f69b53fc261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d59f1adc-846e-450f-bcaf-8f69b53fc261")) {                    Plotly.newPlot(                        "d59f1adc-846e-450f-bcaf-8f69b53fc261",                        [{"hovertemplate": "Name=Steven Adams<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Steven Adams", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Steven Adams", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [0.596, 0.604, 0.591], "yaxis": "y"}, {"hovertemplate": "Name=Bam Adebayo<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Bam Adebayo", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Bam Adebayo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "PF", "C"], "xaxis": "x", "y": [0.626, 0.598, 0.623], "yaxis": "y"}, {"hovertemplate": "Name=LaMarcus Aldridge<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "LaMarcus Aldridge", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "LaMarcus Aldridge", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [0.556, 0.545, 0.571, 0.576], "yaxis": "y"}, {"hovertemplate": "Name=Nickeil Alexander-Walker<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Nickeil Alexander-Walker", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Nickeil Alexander-Walker", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [0.522], "yaxis": "y"}, {"hovertemplate": "Name=Grayson Allen<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Grayson Allen", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Grayson Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [0.586], "yaxis": "y"}, {"hovertemplate": "Name=Jarrett Allen<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Jarrett Allen", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Jarrett Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [0.661, 0.649, 0.664, 0.632], "yaxis": "y"}, {"hovertemplate": "Name=Kyle Anderson<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Kyle Anderson", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Kyle Anderson", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "SF"], "xaxis": "x", "y": [0.578, 0.569], "yaxis": "y"}, {"hovertemplate": "Name=Giannis Antetokounmpo<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Giannis Antetokounmpo", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Giannis Antetokounmpo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "PF", "PF"], "xaxis": "x", "y": [0.633, 0.613, 0.644], "yaxis": "y"}, {"hovertemplate": "Name=Cole Anthony<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "Cole Anthony", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Cole Anthony", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PG"], "xaxis": "x", "y": [0.496], "yaxis": "y"}, {"hovertemplate": "Name=OG Anunoby<br>Pos=%{x}<br>TS%=%{y}<extra></extra>", "legendgroup": "OG Anunoby", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "OG Anunoby", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF", "SF"], "xaxis": "x", "y": [0.605, 0.6, 0.544], "yaxis": "y"}, {"hovertemplate": "Na ...

# %%
px.scatter(player_final, x = 'position', y = 'AST%', color = 'Name')
# Out:
# <div>                            <div id="a15cbf55-0099-4ff3-8262-2b43d951ce2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a15cbf55-0099-4ff3-8262-2b43d951ce2d")) {                    Plotly.newPlot(                        "a15cbf55-0099-4ff3-8262-2b43d951ce2d",                        [{"hovertemplate": "Name=Steven Adams<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Steven Adams", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "Steven Adams", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C"], "xaxis": "x", "y": [9.1, 13.2, 6.6], "yaxis": "y"}, {"hovertemplate": "Name=Bam Adebayo<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Bam Adebayo", "marker": {"color": "#EF553B", "symbol": "circle"}, "mode": "markers", "name": "Bam Adebayo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "PF", "C"], "xaxis": "x", "y": [26.9, 24.2, 14.2], "yaxis": "y"}, {"hovertemplate": "Name=LaMarcus Aldridge<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "LaMarcus Aldridge", "marker": {"color": "#00cc96", "symbol": "circle"}, "mode": "markers", "name": "LaMarcus Aldridge", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [11.0, 10.2, 11.4, 11.6], "yaxis": "y"}, {"hovertemplate": "Name=Nickeil Alexander-Walker<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Nickeil Alexander-Walker", "marker": {"color": "#ab63fa", "symbol": "circle"}, "mode": "markers", "name": "Nickeil Alexander-Walker", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [14.7], "yaxis": "y"}, {"hovertemplate": "Name=Grayson Allen<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Grayson Allen", "marker": {"color": "#FFA15A", "symbol": "circle"}, "mode": "markers", "name": "Grayson Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SG"], "xaxis": "x", "y": [11.5], "yaxis": "y"}, {"hovertemplate": "Name=Jarrett Allen<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Jarrett Allen", "marker": {"color": "#19d3f3", "symbol": "circle"}, "mode": "markers", "name": "Jarrett Allen", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["C", "C", "C", "C"], "xaxis": "x", "y": [8.7, 8.8, 8.9, 7.9], "yaxis": "y"}, {"hovertemplate": "Name=Kyle Anderson<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Kyle Anderson", "marker": {"color": "#FF6692", "symbol": "circle"}, "mode": "markers", "name": "Kyle Anderson", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "SF"], "xaxis": "x", "y": [18.3, 15.0], "yaxis": "y"}, {"hovertemplate": "Name=Giannis Antetokounmpo<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Giannis Antetokounmpo", "marker": {"color": "#B6E880", "symbol": "circle"}, "mode": "markers", "name": "Giannis Antetokounmpo", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PF", "PF", "PF"], "xaxis": "x", "y": [28.7, 34.2, 30.3], "yaxis": "y"}, {"hovertemplate": "Name=Cole Anthony<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "Cole Anthony", "marker": {"color": "#FF97FF", "symbol": "circle"}, "mode": "markers", "name": "Cole Anthony", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["PG"], "xaxis": "x", "y": [24.2], "yaxis": "y"}, {"hovertemplate": "Name=OG Anunoby<br>Pos=%{x}<br>AST%=%{y}<extra></extra>", "legendgroup": "OG Anunoby", "marker": {"color": "#FECB52", "symbol": "circle"}, "mode": "markers", "name": "OG Anunoby", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["SF", "SF", "SF"], "xaxis": "x", "y": [10.1, 7.5, 4.7], "yaxis": "y"}, {"hovertemplate": "Name=Trevor Ariza<br>Po ...

# %% [markdown]
# Changing positions to numbers

# %%
pos_dict = {'PG': 1, 'SG': 2, 'SF': 3, 'PF': 4, 'C': 5}

# %%
# Features under consideration must be numeric and have some relation to position; the columns dropped do not fit this criteria
features = player_final.drop(columns = ['Name', 'Rk', 'position', 'Pos', 'Age', 'team_x', 'team_y', 'G', 'MP', 'Unnamed: 19', 'Unnamed: 24', '#', 'M', 'length'])
target = player_final['position'].replace(pos_dict)
# splits the scaled dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state = 300)
features = X_train.rename(columns = {"Rk": 0, "position": 1, "PER": 2, "TS%": 3, "3PAr": 4, "FTr": 5, "ORB%": 6, "DRB%": 7, "TRB%": 8, "AST%": 9, "STL%": 10, "BLK%": 11, "TOV%": 12, "USG%": 13, "OWS": 14, "DWS": 15, "WS": 16, "WS/48": 17, "OBPM": 18, "DBPM": 19, "BPM": 20, "VORP": 21, "height": 22, "wingspan": 23})

# %% [markdown]
# Selecting features to be used in classifying players by position

# %%
# selects the X most important features to be used for our model
def feature_selection(x_train, x_test, y_train, features, num_feats):
    
    # instantiate
    select = RFE(DecisionTreeRegressor(random_state = 300), n_features_to_select = num_feats)
    
    # fit the RFE selector to the training data
    select.fit(x_train, y_train)
    
    # transform training and testing sets so only the selected features are retained
    X_train_selected = select.transform(x_train)
    X_test_selected = select.transform(x_test)
    
    # prints selected features/Sample Output
    selected_features = [feature for feature, status in zip(features, select.get_support()) if status == True]
    print('Selected features:')
    feats = []
    for feature in selected_features:
        # indexing finds name of statistic instead of index tied to statistic
        print(X_train.columns[feature - 2])
        feats.append(X_train.columns[feature - 2])

    # returns selected features
    return X_train_selected, X_test_selected,  feats

# %%
# performs feature selection/Sample Output
X_train_selected, X_test_selected, feats = feature_selection(X_train, X_test, y_train, features, 5)
# Out:
# Selected features:
# TRB%
# AST%
# USG%
# height
# wingspan

# %%
# dictionary of the classifiers and their names
estimators = {"KNeighborsClassifier": KNeighborsClassifier(),
             "LinearSVC": LinearSVC(random_state = 3000, max_iter = 1000000),
             "GaussianNB": GaussianNB(),
             "DecisionTreeClassifier": DecisionTreeClassifier()}

# sample output
estimators
# Out:
# {'KNeighborsClassifier': KNeighborsClassifier(),
#  'LinearSVC': LinearSVC(max_iter=1000000, random_state=3000),
#  'GaussianNB': GaussianNB(),
#  'DecisionTreeClassifier': DecisionTreeClassifier()}

# %%
# fits the four classifiers using a percentage-split approach
def classifiers_percentage_split():
    # for each classifier in the estimators dictionary
    for estimator_name, estimator_object in estimators.items():
        if (estimator_name == "DecisionTreeClassifier"):
            estimator_object = DecisionTreeClassifier(max_depth = len(X_train_selected[0]))
        # create the model by fitting the selected training data
        estimator_object.fit(X=X_train_selected, y=y_train)

        # make predictions on the test set
        predicted = estimator_object.predict(X = X_test_selected)

        # training accuracy
        train_accuracy = estimator_object.score(X_train_selected, y_train)
        
        # testing accuracy
        test_accuracy = estimator_object.score(X_test_selected, y_test)

        # formats and prints out the results on the test data
        print(estimator_name, ":" , end="")
        print("\n\tPrediction accuracy on the train data:", end=" ")
        print(format(train_accuracy*100, ".2f"), end="") 
        print("%\n\tPrediction accuracy on the test data:", end=" ")
        print(format(test_accuracy*100, ".2f"), end="") 
        print("%\n")
        class_report = classification_report(y_true = y_test, y_pred = predicted)#zero_division = 0)
        print(class_report, "\n------------------------------------------------------\n")

# %%
# fits the four classifiers using a percentage-split approach
def classifiers_performance_data():
    # dataframe with classifier performance metrics recorded
    results = pd.DataFrame()
    # for each classifier in the estimators dictionary
    for estimator_name, estimator_object in estimators.items():
        if (estimator_name == "DecisionTreeClassifier"):
            estimator_object = DecisionTreeClassifier(max_depth = len(X_train_selected[0]))
        # create the model by fitting the selected training data
        estimator_object.fit(X=X_train_selected, y=y_train)

        # make predictions on the test set
        predicted = estimator_object.predict(X = X_test_selected)

        # training accuracy
        train_accuracy = estimator_object.score(X_train_selected, y_train)
        
        # testing accuracy
        test_accuracy = estimator_object.score(X_test_selected, y_test)
        
        results = results.append({'CLF': estimator_name, 'Features': feats,
                                  'Train Accuracy': train_accuracy, 'Test Accuracy': test_accuracy}, ignore_index = True)
    return results

# %%
X_train_selected, X_test_selected, feats = feature_selection(X_train, X_test, y_train, features, 5)
classifiers_percentage_split()
# Out:
# Selected features:
# TRB%
# AST%
# USG%
# height
# wingspan
# KNeighborsClassifier :
# 	Prediction accuracy on the train data: 80.34%
# 	Prediction accuracy on the test data: 67.42%
#
#               precision    recall  f1-score   support
#
#            1       0.71      0.89      0.79        36
#            2       0.82      0.56      0.67        48
#            3       0.47      0.74      0.57        27
#            4       0.59      0.61      0.60        33
#            5       0.91      0.62      0.74        34
#
#     accuracy                           0.67       178
#    macro avg       0.70      0.68      0.67       178
# weighted avg       0.72      0.67      0.68       178
#
# ------------------------------------------------------
#
# LinearSVC :
# 	Prediction accuracy on the train data: 57.30%
# 	Prediction accuracy on the test data: 57.30%
#
#               precision    recall  f1-score   support
#
#            1       0.62      0.83      0.71        36
#            2       0.58      0.71      0.64        48
#            3       0.43      0.22      0.29        27
#            4       0.00      0.00      0.00        33
#            5       0.58      0.94      0.72        34
#
#     accuracy                           0.57       178
#    macro avg       0.44      0.54      0.47       178
# weighted avg       0.46      0.57      0.50       178
#
# ------------------------------------------------------
#
# GaussianNB :
# 	Prediction accuracy on the train data: 65.54%
# 	Prediction accuracy on the test data: 64.04%
#
#               precision    recall  f1-score   support
#
#            1       0.73      0.75      0.74        36
#            2       0.74      0.60      0.67        48
#            3       0.50      0.70      0.58        27
#            4       0.47      0.52      0.49        33
#            5       0.79      0.65      0.71        34
#
#     accuracy                           0.64       178
#    macro avg       0.65      0.64      0.64       178
# weighted avg       0.66      0.64      0.64       178
#
# ------------------------------------------------------
#
# DecisionTreeClassifier :
# 	Prediction accuracy on the train data: 80.34%
# 	Prediction accuracy on the test data: 70.22%
#
#               precision    recall  f1-score   support
#
#            1       0.74      0.86      0.79        36
#            2       0.82      0.69      0.75        48
#            3       0.55      0.67      0.60        27
#            4       0.55      0.67      0.60        33
#            5       0.91      0.62      0.74        34
#
#     accuracy                           0.70       178
#    macro avg       0.71      0.70      0.70       178
# weighted avg       0.73      0.70      0.71       178
#
# ------------------------------------------------------

# %% [markdown]
# GaussianNB with four features (height, wingspan, TRB%, AST%) had the best results in terms of precision

# %%
import sys, os
# Disable
def blockPrint():
    sys.stdout = open(os.devnull, 'w')

# Restore
def enablePrint():
    sys.stdout = sys.__stdout__
blockPrint()
# Compiling accuracy results into a DataFrame to draw conclusions from
final_data = pd.DataFrame()
for num_feats in range(3, 8):
    X_train_selected, X_test_selected, feats = feature_selection(X_train, X_test, y_train, features, num_feats)
    final_data = final_data.append(classifiers_performance_data())
enablePrint()
final_data
# Out:
#                       CLF                                          Features  \
# 0    KNeighborsClassifier                          [AST%, height, wingspan]
# 1               LinearSVC                          [AST%, height, wingspan]
# 2              GaussianNB                          [AST%, height, wingspan]
# 3  DecisionTreeClassifier                          [AST%, height, wingspan]
# 0    KNeighborsClassifier                    [AST%, USG%, height, wingspan]
# 1               LinearSVC                    [AST%, USG%, height, wingspan]
# 2              GaussianNB                    [AST%, USG%, height, wingspan]
# 3  DecisionTreeClassifier                    [AST%, USG%, height, wingspan]
# 0    KNeighborsClassifier              [TRB%, AST%, USG%, height, wingspan]
# 1               LinearSVC              [TRB%, AST%, USG%, height, wingspan]
# 2              GaussianNB              [TRB%, AST%, USG%, height, wingspan]
# 3  DecisionTreeClassifier              [TRB%, AST%, USG%, height, wingspan]
# 0    KNeighborsClassifier        [3PAr, TRB%, AST%, USG%, height, wingspan]
# 1               LinearSVC        [3PAr, TRB%, AST%, USG%, height, wingspan]
# 2              GaussianNB        [3PAr, TRB%, AST%, USG%, height, wingspan]
# 3  DecisionTreeClassifier        [3PAr, TRB%, AST%, USG%, height, wingspan]
# 0    KNeighborsClassifier  [3PAr, TRB%, AST%, USG%, DBPM, height, wingspan]
# 1               LinearSVC  [3PAr, TRB%, AST%, USG%, DBPM, height, wingspan]
# 2              GaussianNB  [3PAr, TRB%, AST%, USG%, DBPM, height, wingspan]
# 3  DecisionTreeClassifier  [3PAr, TRB%, AST%, USG%, DBPM, height, wingspan]
#
#    Test Accuracy  Train Accuracy
# 0       0.623596        0.779026
# 1       0.522472        0.531835
# 2       0.589888        0.651685
# 3       0.578652        0.685393
# 0       0.651685        0.780899
# 1       0.533708        0.548689
# 2       0.567416        0.646067
# 3       0.707865        0.749064
# 0       0.674157        0.803371
# 1       0.573034        0.573034
# 2       0.640449        0.655431
# 3       0.702247        0.803371
# 0       0.674157        0.803371
# 1       0.589888        0.576779
# 2       0.646067        0.661049
# 3       0.702247        0.852060
# 0       0.674157        0.801498
# 1       0.606742        0.578652
# 2       0.668539        0.666667
# 3       0.702247        0.925094

# %%
# function to see predicted value for given player's position
def position_prediction_dtc(player_name):
    
    dtc = DecisionTreeClassifier(max_depth = 5)
    dtc.fit(X=X_train_selected, y=y_train)
    
    player_data = player_final[player_final.Name == player_name]
    player_data = player_data[['TRB%', 'AST%', 'USG%', 'height', 'wingspan']]
    
    # make predictions on the test set
    predicted = dtc.predict(X = player_data)

    return predicted

# %%
# function to see predicted value for given player's position
def position_prediction_gnb(player_name):
    
    gnb = GaussianNB()
    gnb.fit(X=X_train_selected, y=y_train)
    
    player_data = player_final[player_final.Name == player_name]
    player_data = player_data[['TRB%', 'AST%', 'USG%', 'height', 'wingspan']]
    # make predictions on the test set
    predicted = gnb.predict(X = player_data)

    return predicted

# %%
position_prediction_gnb('Joe Ingles')
# Out:
# array([3, 3, 3], dtype=int64)
